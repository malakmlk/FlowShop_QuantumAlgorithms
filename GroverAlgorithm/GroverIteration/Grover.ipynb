# %%
import sys
sys.path.insert(0, 'C:\\Users\\malak\\FlowShop_QuantumAlgorithms\\GroverAlgorithm')

# %%
#import qiskit
from qiskit import QuantumCircuit,ClassicalRegister,QuantumRegister,execute
from qiskit.utils import QuantumInstance
#import Grover operator parts
from oracle1_generator import Oracle1
from oracle2_generator import Oracle2
from Diffuser import diffuser
# import backend in order to run the circuit
from qiskit import *
from typing import List
# Visualization
import matplotlib.pyplot as plt
import numpy as np
from heuristics.FSPHeuristic import FSPHeuristic

# %%
class GroverFlowSop:
    '''
    Grover search algorithm for solving flow shop
    the oracle part of grover is modified in order to distinguish solution
    the same preparation state and diffuser are used
    '''
    def __init__(
        self,
        num_qubits_job : int,
        num_qubits_cmj : int,
        Pm :List[List[int]],
        num_machine : int,
        upperBound : int,
        iterations,
        quantum_instance : QuantumInstance
                 
    )->None :
        '''
        Args :
           - iterations : in order to specify the number of iteration of grover
           - num_qubits_job : nbr of qubits per job.
           - num_qubits_cimj : nbr of qubits per completion time.
           - num_machine : nbr of machines. 
           - Pm : matrix that contain the processing times of all jobs on machines
           - upper_bound : the upper bound.  
           - quantum_instance : A Quantum Instance or Backend to run the circuits.
        Raises :
        ValueError: if iteration = None
        ValueError:if problem = Non
        '''
        if iterations == None :
            raise ValueError("Pass a value of iteration")
      
        self.iterations = iterations
        self._quantum_instance = None
        self.num_qubits_job = num_qubits_job
        self.num_qubits_cimj =num_qubits_cmj
        self.Pm = Pm
        self.num_machine = num_machine
        self.upperBound = upperBound
        if quantum_instance is not None:
            self.quantum_instance = quantum_instance
    
    def GroverOperator(self)-> QuantumCircuit:
        n=self.num_qubits_job
        N=2**(n)
        q=self.num_qubits_cimj
        x=self.Pm
        M=self.num_machine
        up=self.upperBound
        if n != 1 :
            cmp= 2**(n-1)*(N-1)
            nqubits = N*n+2*q+q*(M-1)*(N)+2*q+3+n+cmp+2
            qRegister = QuantumRegister(nqubits)
            qc = QuantumCircuit(qRegister) 
            qc.append(Oracle1(q,n,M,x,up),[i for i in range(N*n+q*(M-1)*(N)+4*q+2)]+[nqubits-3])
            qc.append(Oracle2(N,n),[i for i in range(N*n)]+[i for i in range(N*n+q*(M-1)*(N)+4*q+2,N*n+q*(M-1)*(N)+4*q+2+n+cmp)]+[nqubits-2])
            qc.ccx(qRegister[nqubits-3],qRegister[nqubits-2],qRegister[nqubits-1])
            #reversibility
            qc.append(Oracle1(q,n,M,x,up).inverse(),[i for i in range(N*n+q*(M-1)*(N)+4*q+2)]+[nqubits-3])
            qc.append(Oracle2(N,n).inverse(),[i for i in range(N*n)]+[i for i in range(N*n+q*(M-1)*(N)+4*q+2,N*n+q*(M-1)*(N)+4*q+2+n+cmp)]+[nqubits-2])
        else :  #when N=2 we can reduce the size of the circuit  
            nqubits = N*n+2*q+q*(M-1)*(N)+2*q+3+2
            qRegister = QuantumRegister(nqubits)
            qc = QuantumCircuit(qRegister) 
            qc.append(Oracle1(q,n,M,x,up),[i for i in range(N*n+q*(M-1)*(N)+4*q+2)]+[nqubits-3])
            qc.cx(0,nqubits-2)
            qc.cx(1,nqubits-2)
            qc.ccx(qRegister[nqubits-3],qRegister[nqubits-2],qRegister[nqubits-1])
            #reversibility
            qc.append(Oracle1(q,n,M,x,up).inverse(),[i for i in range(N*n+q*(M-1)*(N)+4*q+2)]+[nqubits-3])
            qc.cx(0,[nqubits-2])
            qc.cx(1,[nqubits-2])
        qc.append(diffuser(n*N),[i for i in range(n*N)])
        return qc
    
    def ConstructCircuit(self)->QuantumCircuit:
            n=self.num_qubits_job
            N=2**(n)
            q=self.num_qubits_cimj
            M=self.num_machine
            if n == 1 :
                nqubits = N*n+2*q+q*(M-1)*(N)+2*q+3+2
                qRegister = QuantumRegister(nqubits)
                qc = QuantumCircuit(qRegister) 
            else :
                cmp= 2**(n-1)*(N-1)
                nqubits = N*n+2*q+q*(M-1)*(N)+2*q+3+n+cmp+2
                qRegister = QuantumRegister(nqubits)
                qc = QuantumCircuit(qRegister)                 
            #state preparation
            qc.h([i for i in range(n*N)])
            qc.x(-1)
            qc.h(-1)
            #Grover operator
            Grover_op= self.GroverOperator()
            for i in range(self.iterations):
                qc.append(Grover_op,qc.qubits)    
            #Measurement     
            measurement_cr = ClassicalRegister(n*N)
            qc.add_register(measurement_cr)
            qc.measure([i for i in range(n*N)], measurement_cr)    
            return qc
    
    def execute(self) -> dict :
        qc = self.ConstructCircuit()
        result = self.quantum_instance.execute(qc)   
        state = result.get_counts(qc)
        shots = self.quantum_instance.run_config.shots
        hist = {key[::-1]: val / shots for key, val in sorted(state.items()) if val > 0}
        self._circuit_results = {b: (v / shots) ** 0.5 for (b, v) in state.items()} 
        return hist

    def memoryEstimationOracle1(self) -> List:
        M=self.num_machine
        n=self.num_qubits_job
        q=self.num_qubits_cimj
        N=2**n
        requiredQubits=N*n+2*q+q*(M-1)*(N)+2*q+3
        requiredMemorySpace = 2**requiredQubits *32/(1024*1024*1024)
        return [requiredQubits,requiredMemorySpace]
        
    #def memoryEstimationOracle2(self):
    def convert_solution_int(self,measurement):
        d = {}
        i,n = 0,self.num_qubits_job
        p = 0
        #measurement = self.execute()
        for perm,prob in measurement.items() :
            for i in range(2**n) :
                p += str(int(perm[i*n:(i+1)*n],2))
            d[p] = prob
            p = ''
        return d
    
    def get_oracle1_results(self):
        # instance 
        n=self.num_qubits_job
        N=2**(n)
        q=self.num_qubits_cimj
        x=self.Pm
        M=self.num_machine
        up=self.upperBound
        
        #Create oracle 1
        nqubits = N*n+2*q+q*(M-1)*(N)+2*q+3
        qRegister = QuantumRegister(nqubits)
        qc = QuantumCircuit(qRegister) 

        # init permutations
        qc.h([i for i in range(n*N)])
        # add oracle gate
        qc.append(Oracle1(q,n,M,x,up),qc.qubits)
        
        #Measurement 
        measurement_rc = ClassicalRegister(n*N + q + 1)
        qc.add_register(measurement_rc)
        qc.measure([i for i in range(n*N)] + [i for i in range(n*N +q+q*(M-1)*N,n*N +2*q + q*(M-1)*N)] +[nqubits -1] ,measurement_rc) 
        result = self.quantum_instance.execute(qc)   
        state = result.get_counts(qc)
        shots = self.quantum_instance.run_config.shots
        results = {key[::-1]: val / shots for key, val in sorted(state.items()) if val > 0}
        self._circuit_results = {b: (v / shots) ** 0.5 for (b, v) in state.items()} 
        return results
    
    def save_results(self,file_path : str,grover_results):
        with open(file_path, 'w') as f:
            for line in grover_results:
                f.write(line)
                f.write('\n')



IBMQ.load_account()
       
my_provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
        
device = my_provider.get_backend("simulator_mps") 
        
quantum_instance = QuantumInstance(device, shots =1000,skip_qobj_validation = False)
PM = [[[4,2,2,1],[2,3,1,3]],[[3,1,2,2,1,3,2,1],[2,2,3,1,4,1,1,1]],[[2,1,1,1,1,3,2,1],[1,2,1,4,1,1,4,1]],[[3,1,4,1,1,2,1,1],[1,3,1,2,1,2,1,1]],[[2,1,1,3,1,3,1,2],[3,1,2,2,3,1,4,1]]]
for i in range(1):
    for it in range(1,4):
        p = PM[i]
        solver = FSPHeuristic(2,4,p)
        results = solver.johnson()
        print(p)
        print(results)
        upper = results[1] +1
        grover = GroverFlowSop(2,5,p,2,upper,it,quantum_instance)
        measurement = grover.execute()
        sys.stdout = open('results.txt', "a+")
        print("instance : " + str(i) + "iteration "+ str(it))
        print(measurement)

#measurement
# Out:
# {'id': 3, 'start_time': 1, 'end_time': 4}
# [[4, 2, 2, 1], [2, 3, 1, 3]]
# ([3, 1, 0, 2], 10, [[{'id': 3, 'start_time': 0, 'end_time': 1}, {'id': 1, 'start_time': 1, 'end_time': 3}, {'id': 0, 'start_time': 3, 'end_time': 7}, {'id': 2, 'start_time': 7, 'end_time': 9}], [{'id': 3, 'start_time': 1, 'end_time': 4}, {'id': 1, 'start_time': 4, 'end_time': 7}, {'id': 0, 'start_time': 7, 'end_time': 9}, {'id': 2, 'start_time': 9, 'end_time': 10}]])
# ibmqjob._wait_for_completion:ERROR:2022-04-28 01:51:19,002: Maximum retries exceeded: Error checking job status due to a network error.
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=172'>173</a> try:
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=173'>174</a>     conn = connection.create_connection(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=174'>175</a>         (self._dns_host, self.port), self.timeout, **extra_kw
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=175'>176</a>     )
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=177'>178</a> except SocketTimeout:
#
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/util/connection.py?line=67'>68</a>     return six.raise_from(
#      <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/util/connection.py?line=68'>69</a>         LocationParseError(u"'%s', label empty or too long" % host), None
#      <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/util/connection.py?line=69'>70</a>     )
# ---> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/util/connection.py?line=71'>72</a> for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/util/connection.py?line=72'>73</a>     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\envs\mk\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/socket.py?line=953'>954</a> addrlist = []
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/socket.py?line=954'>955</a> for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/socket.py?line=955'>956</a>     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=701'>702</a> # Make the request on the httplib connection object.
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=702'>703</a> httplib_response = self._make_request(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=703'>704</a>     conn,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=704'>705</a>     method,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=705'>706</a>     url,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=706'>707</a>     timeout=timeout_obj,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=707'>708</a>     body=body,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=708'>709</a>     headers=headers,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=709'>710</a>     chunked=chunked,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=710'>711</a> )
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=712'>713</a> # If we're going to release the connection in ``finally:``, then
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=713'>714</a> # the response doesn't need to know about the connection. Otherwise
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=714'>715</a> # it will also try to release it and we'll have a double-release
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=715'>716</a> # mess.
#
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=384'>385</a> try:
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=385'>386</a>     self._validate_conn(conn)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=386'>387</a> except (SocketTimeout, BaseSSLError) as e:
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=387'>388</a>     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=1038'>1039</a> if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=1039'>1040</a>     conn.connect()
#    <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=1041'>1042</a> if not conn.is_verified:
#
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=355'>356</a> def connect(self):
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=356'>357</a>     # Add certificate verification
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=357'>358</a>     self.sock = conn = self._new_conn()
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=358'>359</a>     hostname = self.host
#
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=184'>185</a> except SocketError as e:
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=185'>186</a>     raise NewConnectionError(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=186'>187</a>         self, "Failed to establish a new connection: %s" % e
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=187'>188</a>     )
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connection.py?line=189'>190</a> return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000022E593EFBB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\envs\mk\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=438'>439</a> if not chunked:
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=439'>440</a>     resp = conn.urlopen(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=440'>441</a>         method=request.method,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=441'>442</a>         url=url,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=442'>443</a>         body=request.body,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=443'>444</a>         headers=request.headers,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=444'>445</a>         redirect=False,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=445'>446</a>         assert_same_host=False,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=446'>447</a>         preload_content=False,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=447'>448</a>         decode_content=False,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=448'>449</a>         retries=self.max_retries,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=449'>450</a>         timeout=timeout
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=450'>451</a>     )
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=452'>453</a> # Send the request.
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=453'>454</a> else:
#
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=809'>810</a>     log.warning(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=810'>811</a>         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=811'>812</a>     )
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=812'>813</a>     return self.urlopen(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=813'>814</a>         method,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=814'>815</a>         url,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=815'>816</a>         body,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=816'>817</a>         headers,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=817'>818</a>         retries,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=818'>819</a>         redirect,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=819'>820</a>         assert_same_host,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=820'>821</a>         timeout=timeout,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=821'>822</a>         pool_timeout=pool_timeout,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=822'>823</a>         release_conn=release_conn,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=823'>824</a>         chunked=chunked,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=824'>825</a>         body_pos=body_pos,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=825'>826</a>         **response_kw
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=826'>827</a>     )
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=828'>829</a> # Handle redirect?
#
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=809'>810</a>     log.warning(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=810'>811</a>         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=811'>812</a>     )
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=812'>813</a>     return self.urlopen(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=813'>814</a>         method,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=814'>815</a>         url,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=815'>816</a>         body,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=816'>817</a>         headers,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=817'>818</a>         retries,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=818'>819</a>         redirect,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=819'>820</a>         assert_same_host,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=820'>821</a>         timeout=timeout,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=821'>822</a>         pool_timeout=pool_timeout,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=822'>823</a>         release_conn=release_conn,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=823'>824</a>         chunked=chunked,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=824'>825</a>         body_pos=body_pos,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=825'>826</a>         **response_kw
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=826'>827</a>     )
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=828'>829</a> # Handle redirect?
#
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=809'>810</a>     log.warning(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=810'>811</a>         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=811'>812</a>     )
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=812'>813</a>     return self.urlopen(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=813'>814</a>         method,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=814'>815</a>         url,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=815'>816</a>         body,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=816'>817</a>         headers,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=817'>818</a>         retries,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=818'>819</a>         redirect,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=819'>820</a>         assert_same_host,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=820'>821</a>         timeout=timeout,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=821'>822</a>         pool_timeout=pool_timeout,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=822'>823</a>         release_conn=release_conn,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=823'>824</a>         chunked=chunked,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=824'>825</a>         body_pos=body_pos,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=825'>826</a>         **response_kw
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=826'>827</a>     )
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=828'>829</a> # Handle redirect?
#
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=782'>783</a>     e = ProtocolError("Connection aborted.", e)
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=784'>785</a> retries = retries.increment(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=785'>786</a>     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=786'>787</a> )
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/connectionpool.py?line=787'>788</a> retries.sleep()
#
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\providers\ibmq\api\session.py:97, in PostForcelistRetry.increment(self, method, url, response, error, _pool, _stacktrace)
#      <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/session.py?line=94'>95</a>     logger.debug("Retrying method=%s, url=%s, status=%s, error=%s, data=%s, headers=%s",
#      <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/session.py?line=95'>96</a>                  method, url, status, error, data, headers)
# ---> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/session.py?line=96'>97</a> return super().increment(method=method, url=url, response=response,
#      <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/session.py?line=97'>98</a>                          error=error, _pool=_pool, _stacktrace=_stacktrace)
#
# File ~\anaconda3\envs\mk\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/util/retry.py?line=590'>591</a> if new_retry.is_exhausted():
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/util/retry.py?line=591'>592</a>     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/urllib3/util/retry.py?line=593'>594</a> log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api-qcon.quantum-computing.ibm.com', port=443): Max retries exceeded with url: /api/Network/ibm-q/Groups/open/Projects/main/Jobs/6269809acbbf9927cea93df1/status/v/1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022E593EFBB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\providers\ibmq\api\session.py:277, in RetrySession.request(self, method, url, bare, **kwargs)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/session.py?line=275'>276</a> self._log_request_info(url, method, kwargs)
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/session.py?line=276'>277</a> response = super().request(method, final_url, headers=headers, **kwargs)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/session.py?line=277'>278</a> response.raise_for_status()
#
# File ~\anaconda3\envs\mk\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/sessions.py?line=527'>528</a> send_kwargs.update(settings)
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/sessions.py?line=528'>529</a> resp = self.send(prep, **send_kwargs)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/sessions.py?line=530'>531</a> return resp
#
# File ~\anaconda3\envs\mk\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/sessions.py?line=643'>644</a> # Send the request
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/sessions.py?line=644'>645</a> r = adapter.send(request, **kwargs)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/sessions.py?line=646'>647</a> # Total elapsed time of the request (approximately)
#
# File ~\anaconda3\envs\mk\lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=516'>517</a>         raise SSLError(e, request=request)
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=518'>519</a>     raise ConnectionError(e, request=request)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/adapters.py?line=520'>521</a> except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api-qcon.quantum-computing.ibm.com', port=443): Max retries exceeded with url: /api/Network/ibm-q/Groups/open/Projects/main/Jobs/6269809acbbf9927cea93df1/status/v/1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022E593EFBB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# The above exception was the direct cause of the following exception:
#
# RequestsApiError                          Traceback (most recent call last)
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\providers\ibmq\job\ibmqjob.py:911, in IBMQJob._wait_for_completion(self, timeout, wait, required_status, status_queue)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=909'>910</a> try:
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=910'>911</a>     status_response = self._api_client.job_final_status(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=911'>912</a>         self.job_id(), timeout=timeout, wait=wait, status_queue=status_queue)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=912'>913</a> except UserTimeoutExceededError:
#
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\providers\ibmq\api\clients\account.py:401, in AccountClient.job_final_status(self, job_id, timeout, wait, status_queue)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=398'>399</a> if not status_response:
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=399'>400</a>     # Use traditional http requests if websocket not available or failed.
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=400'>401</a>     status_response = self._job_final_status_polling(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=401'>402</a>         job_id, timeout, wait, status_queue)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=403'>404</a> return status_response
#
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\providers\ibmq\api\clients\account.py:466, in AccountClient._job_final_status_polling(self, job_id, timeout, wait, status_queue)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=464'>465</a> start_time = time.time()
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=465'>466</a> status_response = self.job_status(job_id)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=466'>467</a> while ApiJobStatus(status_response['status']) not in API_JOB_FINAL_STATES:
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=467'>468</a>     # Share the new status.
#
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\providers\ibmq\api\clients\account.py:357, in AccountClient.job_status(self, job_id)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=345'>346</a> """Return the status of the job.
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=346'>347</a>
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=347'>348</a> Args:
#    (...)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=354'>355</a>     ApiIBMQProtocolError: If unexpected data is received from the server.
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=355'>356</a> """
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/clients/account.py?line=356'>357</a> return self.account_api.job(job_id).status()
#
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\providers\ibmq\api\rest\job.py:160, in Job.status(self)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/rest/job.py?line=158'>159</a> url = self.get_url('status')
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/rest/job.py?line=159'>160</a> raw_response = self.session.get(url)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/rest/job.py?line=160'>161</a> try:
#
# File ~\anaconda3\envs\mk\lib\site-packages\requests\sessions.py:542, in Session.get(self, url, **kwargs)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/sessions.py?line=540'>541</a> kwargs.setdefault('allow_redirects', True)
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/requests/sessions.py?line=541'>542</a> return self.request('GET', url, **kwargs)
#
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\providers\ibmq\api\session.py:300, in RetrySession.request(self, method, url, bare, **kwargs)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/session.py?line=297'>298</a>         self._modify_chained_exception_messages(ex)
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/session.py?line=299'>300</a>     raise RequestsApiError(message, status_code) from ex
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/api/session.py?line=301'>302</a> return response
#
# RequestsApiError: "HTTPSConnectionPool(host='api-qcon.quantum-computing.ibm.com', port=443): Max retries exceeded with url: /api/Network/ibm-q/Groups/open/Projects/main/Jobs/6269809acbbf9927cea93df1/status/v/1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022E593EFBB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))"
#
# The above exception was the direct cause of the following exception:
#
# IBMQJobApiError                           Traceback (most recent call last)
# c:\Users\malak\FlowShop_QuantumAlgorithms\GroverAlgorithm\GroverIteration\Grover.ipynb Cell 3' in <cell line: 182>()
#     <a href='vscode-notebook-cell:/c%3A/Users/malak/FlowShop_QuantumAlgorithms/GroverAlgorithm/GroverIteration/Grover.ipynb#ch0000002?line=188'>189</a> upper = results[1] +1
#     <a href='vscode-notebook-cell:/c%3A/Users/malak/FlowShop_QuantumAlgorithms/GroverAlgorithm/GroverIteration/Grover.ipynb#ch0000002?line=189'>190</a> grover = GroverFlowSop(2,5,p,2,upper,it,quantum_instance)
# --> <a href='vscode-notebook-cell:/c%3A/Users/malak/FlowShop_QuantumAlgorithms/GroverAlgorithm/GroverIteration/Grover.ipynb#ch0000002?line=190'>191</a> measurement = grover.execute()
#     <a href='vscode-notebook-cell:/c%3A/Users/malak/FlowShop_QuantumAlgorithms/GroverAlgorithm/GroverIteration/Grover.ipynb#ch0000002?line=191'>192</a> sys.stdout = open('results.txt', "a+")
#     <a href='vscode-notebook-cell:/c%3A/Users/malak/FlowShop_QuantumAlgorithms/GroverAlgorithm/GroverIteration/Grover.ipynb#ch0000002?line=192'>193</a> print("instance : " + str(i) + "iteration "+ str(it))
#
# c:\Users\malak\FlowShop_QuantumAlgorithms\GroverAlgorithm\GroverIteration\Grover.ipynb Cell 3' in GroverFlowSop.execute(self)
#     <a href='vscode-notebook-cell:/c%3A/Users/malak/FlowShop_QuantumAlgorithms/GroverAlgorithm/GroverIteration/Grover.ipynb#ch0000002?line=104'>105</a> def execute(self) -> dict :
#     <a href='vscode-notebook-cell:/c%3A/Users/malak/FlowShop_QuantumAlgorithms/GroverAlgorithm/GroverIteration/Grover.ipynb#ch0000002?line=105'>106</a>     qc = self.ConstructCircuit()
# --> <a href='vscode-notebook-cell:/c%3A/Users/malak/FlowShop_QuantumAlgorithms/GroverAlgorithm/GroverIteration/Grover.ipynb#ch0000002?line=106'>107</a>     result = self.quantum_instance.execute(qc)
#     <a href='vscode-notebook-cell:/c%3A/Users/malak/FlowShop_QuantumAlgorithms/GroverAlgorithm/GroverIteration/Grover.ipynb#ch0000002?line=107'>108</a>     state = result.get_counts(qc)
#     <a href='vscode-notebook-cell:/c%3A/Users/malak/FlowShop_QuantumAlgorithms/GroverAlgorithm/GroverIteration/Grover.ipynb#ch0000002?line=108'>109</a>     shots = self.quantum_instance.run_config.shots
#
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\utils\quantum_instance.py:801, in QuantumInstance.execute(self, circuits, had_transpiled)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=796'>797</a>                 result.results[n] = tmp_result.results[i]
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=798'>799</a> else:
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=799'>800</a>     result = (
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=800'>801</a>         run_circuits(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=801'>802</a>             circuits,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=802'>803</a>             self._backend,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=803'>804</a>             qjob_config=self.qjob_config,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=804'>805</a>             backend_options=self.backend_options,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=805'>806</a>             noise_config=self._noise_config,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=806'>807</a>             run_config=self._run_config.to_dict(),
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=807'>808</a>             job_callback=self._job_callback,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=808'>809</a>             max_job_retries=self._max_job_retries,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=809'>810</a>         )
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=810'>811</a>         if circuit_job
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=811'>812</a>         else run_qobj(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=812'>813</a>             qobj,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=813'>814</a>             self._backend,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=814'>815</a>             self._qjob_config,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=815'>816</a>             self._backend_options,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=816'>817</a>             self._noise_config,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=817'>818</a>             self._skip_qobj_validation,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=818'>819</a>             self._job_callback,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=819'>820</a>             self._max_job_retries,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=820'>821</a>         )
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=821'>822</a>     )
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=822'>823</a>     self._time_taken += result.time_taken
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/quantum_instance.py?line=824'>825</a> if self._circuit_summary:
#
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\utils\run_circuits.py:623, in run_circuits(circuits, backend, qjob_config, backend_options, noise_config, run_config, job_callback, max_job_retries)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/run_circuits.py?line=620'>621</a>     results = []
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/run_circuits.py?line=621'>622</a>     for job in jobs:
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/run_circuits.py?line=622'>623</a>         results.append(job.result())
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/run_circuits.py?line=624'>625</a> result = _combine_result_objects(results) if results else None
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/run_circuits.py?line=625'>626</a> # If result was not successful then raise an exception with either the status msg or
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/utils/run_circuits.py?line=626'>627</a> # extra information if this was an Aer partial result return
#
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\providers\ibmq\job\ibmqjob.py:276, in IBMQJob.result(self, timeout, wait, partial, refresh)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=225'>226</a> """Return the result of the job.
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=226'>227</a>
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=227'>228</a> Note:
#    (...)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=272'>273</a>         with the server.
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=273'>274</a> """
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=274'>275</a> # pylint: disable=arguments-differ
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=275'>276</a> if not self._wait_for_completion(timeout=timeout, wait=wait,
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=276'>277</a>                                  required_status=(JobStatus.DONE,)):
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=277'>278</a>     if self._status is JobStatus.CANCELLED:
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=278'>279</a>         raise IBMQJobInvalidStateError('Unable to retrieve result for job {}. '
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=279'>280</a>                                        'Job was cancelled.'.format(self.job_id()))
#
# File ~\anaconda3\envs\mk\lib\site-packages\qiskit\providers\ibmq\job\ibmqjob.py:919, in IBMQJob._wait_for_completion(self, timeout, wait, required_status, status_queue)
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=915'>916</a> except ApiError as api_err:
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=916'>917</a>     logger.error('Maximum retries exceeded: '
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=917'>918</a>                  'Error checking job status due to a network error.')
# --> <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=918'>919</a>     raise IBMQJobApiError('Error checking job status due to a network '
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=919'>920</a>                           'error: {}'.format(str(api_err))) from api_err
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=921'>922</a> self._api_status = status_response['status']
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=922'>923</a> self._status, self._queue_info = self._get_status_position(
#     <a href='file:///c%3A/Users/malak/anaconda3/envs/mk/lib/site-packages/qiskit/providers/ibmq/job/ibmqjob.py?line=923'>924</a>     self._api_status, status_response.get('info_queue', None))
#
# IBMQJobApiError: 'Error checking job status due to a network error: "HTTPSConnectionPool(host=\'api-qcon.quantum-computing.ibm.com\', port=443): Max retries exceeded with url: /api/Network/ibm-q/Groups/open/Projects/main/Jobs/6269809acbbf9927cea93df1/status/v/1 (Caused by NewConnectionError(\'<urllib3.connection.HTTPSConnection object at 0x0000022E593EFBB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed\'))"'

# %%
print(PM[0])
